# %%
import model_loader
import pipeline
from PIL import Image
from pathlib import Path
from transformers import CLIPTokenizer
import torch

DEVICE = "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device: {DEVICE}")

tokenizer = CLIPTokenizer(r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\tokenizer_vocab.json", 
                          merges_file=r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\tokenizer_merges.txt")
model_file = r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

## TEXT TO IMAGE

# prompt = "A dog with sunglasses, wearing comfy hat, looking at camera, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
prompt = "A cat stretching on the floor, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
uncond_prompt = ""  # Also known as negative prompt
do_cfg = True
cfg_scale = 8  # min: 1, max: 14

## IMAGE TO IMAGE

input_image = None
# Comment to disable image to image
image_path = r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\image\vecteezy_funny-portrait-of-cute-corgi-dog-outdoors_5857332.jpg"
# input_image = Image.open(image_path)
# Higher values means more noise will be added to the input image, so the result will further from the input image.
# Lower values means less noise is added to the input image, so output will be closer to the input image.
strength = 0.9

## SAMPLER

sampler = "ddpm"
num_inference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)

# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
# Out:
# C:\Users\soods\AppData\Local\Temp\ipykernel_5344\3822021616.py:15: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
# Using device: cpu
# 100%|██████████| 50/50 [40:22<00:00, 48.44s/it]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import model_loader
import pipeline
from PIL import Image
from pathlib import Path
from transformers import CLIPTokenizer
import torch

DEVICE = "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device: {DEVICE}")

tokenizer = CLIPTokenizer(r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\tokenizer_vocab.json", 
                          merges_file=r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\tokenizer_merges.txt")
model_file = r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

## TEXT TO IMAGE

# prompt = "A dog with sunglasses, wearing comfy hat, looking at camera, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
prompt = "A black panther animal on tree in night , 100mm lens, 8k resolution"
uncond_prompt = ""  # Also known as negative prompt
do_cfg = True
cfg_scale = 8  # min: 1, max: 14

## IMAGE TO IMAGE

input_image = None
# Comment to disable image to image
image_path = r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\image\vecteezy_funny-portrait-of-cute-corgi-dog-outdoors_5857332.jpg"
# input_image = Image.open(image_path)
# Higher values means more noise will be added to the input image, so the result will further from the input image.
# Lower values means less noise is added to the input image, so output will be closer to the input image.
strength = 0.9

## SAMPLER

sampler = "ddpm"
num_inference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)

# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
# Out:
# C:\Users\soods\AppData\Local\Temp\ipykernel_8960\4283352405.py:15: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
# Using device: cpu
# 100%|██████████| 50/50 [38:04<00:00, 45.69s/it]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import model_loader
import pipeline
from PIL import Image
from pathlib import Path
from transformers import CLIPTokenizer
import torch

DEVICE = "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device: {DEVICE}")

tokenizer = CLIPTokenizer(r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\tokenizer_vocab.json", 
                          merges_file=r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\tokenizer_merges.txt")
model_file = r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\Data\v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

## TEXT TO IMAGE

prompt = "A dog with sunglasses, wearing comfy hat, looking at camera, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
# prompt = "cchange background"
uncond_prompt = ""  # Also known as negative prompt
do_cfg = True
cfg_scale = 8  # min: 1, max: 14

## IMAGE TO IMAGE

input_image = None
# Comment to disable image to image
image_path = r"C:\Users\soods\OneDrive\Desktop\difdusion\pytorch-stable-diffusion\image\vecteezy_funny-portrait-of-cute-corgi-dog-outdoors_5857332.jpg"
input_image = Image.open(image_path)
# Higher values means more noise will be added to the input image, so the result will further from the input image.
# Lower values means less noise is added to the input image, so output will be closer to the input image.
strength = 0.5

## SAMPLER

sampler = "ddpm"
num_inference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)

# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
# Out:
# C:\Users\soods\AppData\Local\Temp\ipykernel_8560\4011442991.py:15: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   elif (torch.has_mps or torch.backends.mps.is_available()) and ALLOW_MPS:
# Using device: cpu
# 100%|██████████| 25/25 [17:43<00:00, 42.55s/it]
# <PIL.Image.Image image mode=RGB size=512x512>
